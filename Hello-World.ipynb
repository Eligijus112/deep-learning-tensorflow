# %% [markdown]
# # Hello world of neural networks

# %% [markdown]
# ## Quick overview of a simple feedforward neural network

# %% [markdown]
# A neural network is a type of machine learning algorythm which models itself after the human brain, creating an artificial neural network that allows the computer to learn by incorporating new data.

# %% [markdown]
# ![NN_schema.png](attachment:NN_schema.png)

# %% [markdown]
# Each circle in the above diagram is called a **neuron**.
#
# Each neuron has an **activation function**.
#
# Most of the basic neural networks have an **input layer**, at least one **hidden layer** and and **output layer**.
#
# The arrows in the above diagram are called **connections**. Each connection provides the output of one neuron as an input to another neuron. Each connection is assigned a **weight** that represents its relative importance.
#
# Given an input, the network **forward propagates** the data via all the network and makes a prediction of $\hat{y}$ and an error is calculated, for example, $E:=(y - \hat{y})^{2}$. Then, during **backpropogation**, all the weights of the network are readjusted in such a way that the connections that had the biggest impact to the error are diminished.
#
# One iteration of feedforward and backpropogation is called an **epoch**.

# %% [markdown]
# There are a lot of resources that explain every bolded term. I will assume that the reader has at least an intuitive understanding of the concepts of deep learning and focus more on the implementation of neural networks in tensorflow and keras.

# %% [markdown]
# ## Tensorflow and Keras

# %% [markdown]
# TensorFlow (**tf** for short) is an end-to-end open source platform for machine learning. It has a comprehensive, flexible ecosystem of tools, libraries and community resources that lets researchers push the state-of-the-art in ML and developers easily build and deploy ML powered applications.
#
# As the name suggests, tensorflow deal with the *flow* of *tensors*. The flow represents the forward and back propogations and tensors are data represented as tensors.
#
# Throughout every notebook, I will be using tensorflow version **2.0.0**.
#
# Keras is a high-level neural networks API, written in Python and capable of running on top of TensorFlow. It was developed with a focus on enabling fast experimentation. Being able to go from idea to result with the least possible delay is key to doing good research.
#
# To summarize, one can view the relationship between tensorflow and keras as tensorflow beeing used for deep calculations in the computer backend and keras is an API to query the backend.

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# ## A very simple neural network

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Let us imagine that we have a simple function
#
# $$y:= f(x) = x * 2 - 1$$

# %% [markdown]
# Lets define that function in python:

# %%
def f(x) -> float: 
    """
    A simple function
    """
    return x * 2 - 1

# %% [markdown]
# Creating some points:

# %%
xs = [0, 1, 2, 3, 4, 5]
ys = [f(x) for x in xs]

# %%
print(f"""
{xs}
{ys}
""")
# Out:
# [0, 1, 2, 3, 4, 5]
# [-1, 1, 3, 5, 7, 9]

# %%
plt.plot(xs, ys)
plt.show()

# %% [markdown]
# Lets us define a neural network to find the relationship just with the data points and without any knowledge of the true relationship between x and y.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The above neural network will have one input neuron and one hidden layer.
#
# **tf.keras.Sequantial** initiates a sequantial model, which is just a simple feedfoward fully connected neural network.
#
# **keras.layer.Dense** creates a layer of neurons (just one in this case) with a precoded input shape.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# The term 'sgd' stands for stochastic gradient descent. The loss function is
# $$loss(y, \hat{y}) =  \dfrac{1}{n} \sum (y - \hat{y})^{2}$$

# %% [markdown]
# I will wrap everything into a function:

# %%
def approx_f(xs, ys, epochs):
    """
    A method to train a neural network
    """
    model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
    model.compile(optimizer='sgd', loss='mean_squared_error')
    model.fit(xs, ys, epochs=epochs)
    
    return model

# %%
model = approx_f(xs, ys, 50)
# Out:
# Train on 6 samples
# Epoch 1/50
# 6/6 [==============================] - 0s 53ms/sample - loss: 5.3128
# Epoch 2/50
# 6/6 [==============================] - 0s 997us/sample - loss: 3.5776
# Epoch 3/50
# 6/6 [==============================] - 0s 1ms/sample - loss: 2.4581
# Epoch 4/50
# 6/6 [==============================] - 0s 996us/sample - loss: 1.7352
# Epoch 5/50
# 6/6 [==============================] - 0s 1ms/sample - loss: 1.2677
# Epoch 6/50
# 6/6 [==============================] - 0s 998us/sample - loss: 0.9649
# Epoch 7/50
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.7681
# Epoch 8/50
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.6395
# Epoch 9/50
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.5551
# Epoch 10/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.4990
# Epoch 11/50
# 6/6 [==============================] - 0s 999us/sample - loss: 0.4612
# Epoch 12/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.4352
# Epoch 13/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.4168
# Epoch 14/50
# 6/6 [==============================] - 0s 835us/sample - loss: 0.4033
# Epoch 15/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.3931
# Epoch 16/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3849
# Epoch 17/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3781
# Epoch 18/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.3722
# Epoch 19/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3668
# Epoch 20/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3619
# Epoch 21/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3573
# Epoch 22/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3528
# Epoch 23/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.3485
# Epoch 24/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3443
# Epoch 25/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3401
# Epoch 26/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.3361
# Epoch 27/50
# 6/6 [==============================] - 0s 2ms/sample - loss: 0.3321
# Epoch 28/50
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.3282
# Epoch 29/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3243
# Epoch 30/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.3205
# Epoch 31/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3167
# Epoch 32/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.3129
# Epoch 33/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3093
# Epoch 34/50
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.3056
# Epoch 35/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.3020
# Epoch 36/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2984
# Epoch 37/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2949
# Epoch 38/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.2915
# Epoch 39/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2880
# Epoch 40/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.2846
# Epoch 41/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2813
# Epoch 42/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2780
# Epoch 43/50
# 6/6 [==============================] - 0s 998us/sample - loss: 0.2747
# Epoch 44/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.2714
# Epoch 45/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2682
# Epoch 46/50
# 6/6 [==============================] - 0s 837us/sample - loss: 0.2651
# Epoch 47/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2620
# Epoch 48/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2589
# Epoch 49/50
# 6/6 [==============================] - 0s 997us/sample - loss: 0.2558
# Epoch 50/50
# 6/6 [==============================] - 0s 831us/sample - loss: 0.2528

# %% [markdown]
# After each epoch we can see the loss function's value. In general, this value should decrease with every epoch.

# %%
model.predict([6])[0]
# Out:
# array([10.388476], dtype=float32)

# %%
f(6)
# Out:
# 11

# %% [markdown]
# As we can see, the true value of the function with x=6 is close to the predicted value of our neural network. By increasing the number of epochs, we can achieve better accuracy.
